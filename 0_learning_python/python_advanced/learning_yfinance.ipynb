# %%
import yfinance as yf

#Wichtig Theorie: Ticker + Tickers, Dataframe, Zeitpunkte
# Übungsaufgabe: Hole Daten von 6 Aktien der letzten 3 jahre udn rechne deren durchschnittswerte aus für jedes jahr 2022,2023,2024
# Übungsaufgabe: Welche aktie von den 6 hat 2024 die höchste rendite erzielt?
